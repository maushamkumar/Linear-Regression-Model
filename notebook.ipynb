# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %% [markdown]
# # The diabetes dataset
# The built-in diabetes dataset includes 442 samples of data around diabetesm with 10 feature variables, some of which include:

# %% [markdown]
# In a new code cell, load the daibetes dataset by calling load_diabetes(). The input return_x_y=True signals that x will be a data matrix, and y will be the regression target.

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %% [markdown]
# There is 442 rows and 10 columns.

# %% [markdown]
# You can see that this data has 442 items shaped in arrays of 10 elements

# %% [markdown]
# Think a bit about the relationship between the data and the regression target. Linear regression predicts relationships between feature X and target variable y. so we have to find target variable in diabetes dataset documentation. what is the target variable

# %% [markdown]
# Next, select a portion of this dataset to plot by arranging it into a new array using numpy's newaxis function. we are going to use linear regression to generate a line between values in this data, according to a pattern it determines.

# %%
X = X[:, np.newaxis, 2]

# %%
X
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %% [markdown]
# Train Test split

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %% [markdown]
# Now you are ready to train your model! Load up the linear regression model and train it with your X and y training sets using model.fit()

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Then, create a prediction using test data, using the function predict(). This will be used to draw the line between data groups

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Let's plot the data using Matplotlib. and we are ploting scatter plot of all the X and y test data, and we also the prediction to draw a line in the most appropriate place, between the model's data groupings.

# %%
plt.scatter(X_test, y_test, color="red")
plt.plot(X_test, y_pred, color="black", linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title("A Graph plot showing Diabetes Progression Against BMI")
plt.show()
